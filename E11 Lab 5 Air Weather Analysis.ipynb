# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
indoor_df = pd.read_csv('air_weather_indoors.csv')
outdoor_df = pd.read_csv('air_weather_outdoors.csv')

indoor_df = indoor_df.drop(index=0)
outdoor_df = outdoor_df.drop(index=0)

# %%
for i in range(1,len(indoor_df.columns)):
    plt.figure(i)
    plt.plot(indoor_df['t_s'],indoor_df[indoor_df.columns[i]]) 
    plt.xlabel('Time (s)')
    plt.ylabel(indoor_df.columns[i])
    plt.title(f'Indoor {indoor_df.columns[i]} vs Time')

# %%
for i in range(1,len(outdoor_df.columns)):
    plt.figure(i)
    plt.plot(outdoor_df['t_s'],outdoor_df[outdoor_df.columns[i]]) 
    plt.xlabel('Time (s)')
    plt.ylabel(outdoor_df.columns[i])
    plt.title(f'Outdoor {outdoor_df.columns[i]} vs Time')

# %%
for i in range(1,len(indoor_df.columns)):
    plt.figure(i)
    plt.plot(indoor_df['t_s'],indoor_df[indoor_df.columns[i]],label="Indoor") 
    plt.plot(outdoor_df['t_s'],outdoor_df[outdoor_df.columns[i]], label="Outdoor")
    plt.xlabel('Time (s)')
    plt.ylabel(indoor_df.columns[i])
    plt.legend()
    plt.title(f'{indoor_df.columns[i]} vs Time')

# %%
for i in range(1,len(indoor_df.columns)):
    combined_min = min(min(indoor_df[indoor_df.columns[i]]), min(outdoor_df[outdoor_df.columns[i]]))
    combined_max = max(max(indoor_df[indoor_df.columns[i]]), max(outdoor_df[outdoor_df.columns[i]]))
    shared_bins = np.linspace(combined_min,combined_max,25)
    plt.figure(i)
    plt.hist(indoor_df[indoor_df.columns[i]],label="Indoor", bins=shared_bins) 
    plt.hist(outdoor_df[outdoor_df.columns[i]], label="Outdoor", bins=shared_bins)
    plt.xlabel('Time (s)')
    plt.ylabel(indoor_df.columns[i])
    plt.legend()
    plt.title(f'{indoor_df.columns[i]} vs Time')

# %%
for i in range(1,len(indoor_df.columns)):
    indoor_mean = np.mean(indoor_df[indoor_df.columns[i]]) 
    outdoor_mean = np.mean(outdoor_df[outdoor_df.columns[i]])
    indoor_uncertainty = indoor_mean/np.sqrt(len(indoor_df.columns))
    outdoor_uncertainty = outdoor_mean/np.sqrt(len(outdoor_df.columns))
    print(f'Indoor mean: {indoor_mean}, outdoor mean: {outdoor_mean}, uncertainty separation: {(indoor_uncertainty-outdoor_uncertainty)}, mean separation: {3*(indoor_mean-outdoor_mean)}')
# Out:
# Indoor mean: 23.24662162162162, outdoor mean: 18.648310810810813, uncertainty separation: 1.149577702702702, mean separation: 13.794932432432425
# Indoor mean: 102654.25, outdoor mean: 158376.99662162163, uncertainty separation: -13930.686655405407, mean separation: -167168.23986486488
# Indoor mean: 32.55472972972973, outdoor mean: 39.06587837837838, uncertainty separation: -1.6277871621621625, mean separation: -19.53344594594595
# Indoor mean: 1006.3612162162163, outdoor mean: 1006.3258547297297, uncertainty separation: 0.00884037162165896, mean separation: 0.10608445945990752
# Indoor mean: 57.51233108108107, outdoor mean: 57.80929054054054, uncertainty separation: -0.07423986486486633, mean separation: -0.890878378378396
# Indoor mean: 0.6959459459459459, outdoor mean: 2.435810810810811, uncertainty separation: -0.43496621621621623, mean separation: -5.219594594594595
# Indoor mean: 0.6959459459459459, outdoor mean: 2.435810810810811, uncertainty separation: -0.43496621621621623, mean separation: -5.219594594594595
# Indoor mean: 0.3108108108108108, outdoor mean: 1.7804054054054055, uncertainty separation: -0.3673986486486487, mean separation: -4.408783783783784
# Indoor mean: 0.9054054054054054, outdoor mean: 2.6182432432432434, uncertainty separation: -0.42820945945945954, mean separation: -5.138513513513514
# Indoor mean: 222.16216216216216, outdoor mean: 448.9155405405405, uncertainty separation: -56.68834459459459, mean separation: -680.2601351351351
# Indoor mean: 62.75675675675676, outdoor mean: 121.65878378378379, uncertainty separation: -14.725506756756758, mean separation: -176.7060810810811
# Indoor mean: 7.037162162162162, outdoor mean: 14.925675675675675, uncertainty separation: -1.9721283783783783, mean separation: -23.66554054054054
# Indoor mean: 0.38175675675675674, outdoor mean: 1.114864864864865, uncertainty separation: -0.18327702702702703, mean separation: -2.1993243243243246
# Indoor mean: 0.26013513513513514, outdoor mean: 0.10135135135135136, uncertainty separation: 0.03969594594594594, mean separation: 0.4763513513513513
# Indoor mean: 0.10135135135135136, outdoor mean: 0.10135135135135136, uncertainty separation: 0.0, mean separation: 0.0
